# %% [markdown]
# Once we have the GAM Rashomon set, we can use it for various applications. We show examples for 5 different applications in this notebook.
# - Application 1: get different GAM models from the Rashomon set.
# - Application 2: get variable importance range.
# - Application 3: find the model that satisfies the monotonic constraints.
# - Application 4: find the users' preferred shape functions.
# - Application 5: explore sudden changes or abnormal patterns in the shape function.

# %%
import numpy as np
import pandas as pd
import pickle
# !pip install rpy2
from src.run_app import *
from src.prepare_gam import *
from matplotlib import pyplot as plt
import pickle as pkl
from src.utils import *

# %% [markdown]
# Specify the filepath which stores the Rashomon set of a sparse GAM model.

# %%
import numpy as np
import pandas as pd
import pickle
# !pip install rpy2
from src.run_app import *
from src.prepare_gam import *
from matplotlib import pyplot as plt
import pickle as pkl
from src import utils

# dataset_name = 'diabetes'
# path = '/usr/project/xtmp/vb97/GAM_Rashomon_Sets/GAMsRashomonSet/datasets/{}.csv'.format(
#     dataset_name)
# dataset = pd.read_csv(path)
# dataset.iloc[:,-1][dataset.iloc[:,-1] == 0] = -1
# X,y = dataset.iloc[:,:-1], dataset.iloc[:,-1]
# X_one_hot, count = one_hot_encoding(X,one_hot=False)
# y = pd.DataFrame(y) # {0,1}
# header = list(X_one_hot.columns)
# header = pd.Index(["intercept"] + header)
# header = header.astype("object")
# print("header dimension", len(header), flush=True)
# X_one_hot, y = utils.get_X_y(X_one_hot, y) # add a column of one to X_orig and make y in {1,-1}
# y = y[:,-1]
# print(X_one_hot.shape,y.shape)

betas_fastSparse = prepare_sparse_gam('compas',lamb0=0.0001,lamb2=1e-3,multiplier=1.01)
# Out:
# header dimension 142
# lamb0:0.0001, lamb2:0.001, acc:0.6881424641667874, auc:0.741277454066303, supp_size:27
# pair before removing {'sex=female': [0.0], 'age': [19.0, 20.0, 22.0, 24.0, 27.0, 29.0, 33.0, 36.0, 39.0, 40.0, 52.0, 83.0], 'juv_misd_count': [0.0, 5.0], 'juvenile_crimes': [0.0, 7.0], 'priors_count': [0.0, 1.0, 2.0, 5.0, 7.0, 9.0, 15.0, 20.0], 'current_charge_degree=felony': [0.0]}
# k, v sex=female [0.0, 1]
# k, v age [19.0, 20.0, 22.0, 24.0, 27.0, 29.0, 33.0, 36.0, 39.0, 40.0, 52.0, 83.0, 96]
# k, v juv_misd_count [0.0, 5.0, 13]
# k, v juvenile_crimes [0.0, 7.0, 20]
# k, v priors_count [0.0, 1.0, 2.0, 5.0, 7.0, 9.0, 15.0, 20.0, 38]
# k, v current_charge_degree=felony [0.0, 1]
# pair after removing {'sex=female': [0.0, 1], 'age': [19.0, 20.0, 22.0, 24.0, 27.0, 29.0, 33.0, 36.0, 39.0, 40.0, 52.0, 83.0, 96], 'juv_misd_count': [0.0, 5.0, 13], 'juvenile_crimes': [0.0, 7.0, 20], 'priors_count': [0.0, 1.0, 2.0, 5.0, 7.0, 9.0, 15.0, 20.0, 38], 'current_charge_degree=felony': [0.0, 1]}
# v_count: [0, 2, 13, 3, 3, 9, 2]
# [ 0  2 15 18 21 30 32]
# sex=female 0 0
# sex=female 1 1
# age 0 2
# age 1 3
# age 2 4
# age 3 5
# age 4 6
# age 5 7
# age 6 8
# age 7 9
# age 8 10
# age 9 11
# age 10 12
# age 11 13
# age 12 14
# juv_misd_count 0 15
# juv_misd_count 1 16
# juv_misd_count 2 17
# juvenile_crimes 0 18
# juvenile_crimes 1 19
# juvenile_crimes 2 20
# priors_count 0 21
# priors_count 1 22
# priors_count 2 23
# priors_count 3 24
# priors_count 4 25
# priors_count 5 26
# priors_count 6 27
# priors_count 7 28
# priors_count 8 29
# current_charge_degree=felony 0 30
# current_charge_degree=felony 1 31
# True
# True
# True
# True
# True
# True
# (33,) hi
# (33,) hi2
# (6907, 33) (33,) (6907, 33) (33,)
# objective: 0.5971756328038138 objective in LR 0.5971756328038138
# m:1.01, log objective:0.5971756328038138, eps:0.603147389131852

# %% [markdown]
# ## Application 1: get different models from the Rashomon set.

# %%
dname = "compas"
l0 = 0.0001
l2 = 0.001
m = 1.01
filepath = "{}_{}_{}_{}.p".format(dname, l0, l2, m)

w_samples = get_models_from_rset(filepath, n_samples=100, plot_shape=True,sample_from_surface=False)

# %%
for i in range(len(w_samples)):
    w0 = w_samples[i,:]
    X_fastsparse = pkl.load(open(betas_fastSparse,'rb'))['X']
    logits = X_fastsparse@w0
    y_pred = np.exp(logits)/(1+np.exp(logits))
    y_pred[y_pred > 0.5] = 1
    y_pred[y_pred <=0.5] = -1
    print((y!=y_pred).mean(),len(pkl.load(open(betas_fastSparse,'rb'))['header_new']))
# Out:
# 0.4333285073114232 33
# 0.3922108006370349 33
# 0.38511654842912985 33
# 0.39785724627189806 33
# 0.486607789199363 33
# 0.43130157810916464 33
# 0.38714347763138846 33
# 0.46185029680034745 33
# 0.3717967279571449 33
# 0.38902562617634284 33
# 0.460692051541914 33
# 0.4491095989575793 33
# 0.440277978862024 33
# 0.39264514260894745 33
# 0.46387722600260606 33
# 0.4540321413059215 33
# 0.37324453453018674 33
# 0.3958303170696395 33
# 0.4372375850586362 33
# 0.438685391631678 33
# 0.40639930505284494 33
# 0.3681772115245403 33
# 0.4176921963225713 33
# 0.38989431012016795 33
# 0.42637903576082237 33
# 0.4247864485304763 33
# 0.389170406833647 33
# 0.4488200376429709 33
# 0.38149703199652524 33
# 0.38352396119878385 33
# 0.4019111046764152 33
# 0.404082814535978 33
# 0.3806283480527002 33
# 0.4223251773563052 33
# 0.398581149558419 33
# 0.3607933980020269 33
# 0.4129144346315332 33
# 0.3861300130302592 33
# 0.42985377153612275 33
# 0.42377298392934704 33
# 0.42912986824960186 33
# 0.41609960909222526 33
# 0.4043723758505864 33
# 0.455190386564355 33
# 0.5087592297669031 33
# 0.42623425510351814 33
# 0.37338931518749097 33
# 0.367163746923411 33
# 0.40900535688432027 33
# 0.40972926017084116 33
# 0.43550021717098597 33
# 0.4010424207325901 33
# 0.409584479513537 33
# 0.4418705660923701 33
# 0.4352106558563776 33
# 0.45200521210366296 33
# 0.43622412045750686 33
# 0.4889242797162299 33
# 0.3932242652381642 33
# 0.39235558129433906 33
# 0.4123353120023165 33
# 0.4430288113508035 33
# 0.40364847256406544 33
# 0.38960474880555956 33
# 0.3966990010134646 33
# 0.4192847835529173 33
# 0.4101636021427537 33
# 0.4178369769798755 33
# 0.42768206167656003 33
# 0.43318372665411903 33
# 0.4037932532213696 33
# 0.42218039669900104 33
# 0.3867091356594759 33
# 0.42522079050238887 33
# 0.3952511944404228 33
# 0.40277978862024033 33
# 0.39076299406399306 33
# 0.46228463877226 33
# 0.4452005212103663 33
# 0.43839583031706963 33
# 0.4359345591428985 33
# /tmp/ipykernel_778941/3372660665.py:5: RuntimeWarning: overflow encountered in exp
#   y_pred = np.exp(logits)/(1+np.exp(logits))
# /tmp/ipykernel_778941/3372660665.py:5: RuntimeWarning: invalid value encountered in divide
#   y_pred = np.exp(logits)/(1+np.exp(logits))
# 0.389170406833647 33
# 0.4586651223396554 33
# 0.36586072100767336 33
# 0.4029245692775445 33
# 0.4201534674967424 33
# 0.46764152309251483 33
# 0.46112639351382656 33
# 0.3975676849572897 33
# 0.37773273490661646 33
# 0.46025770957000145 33
# 0.4156652671203127 33
# 0.4268133777327349 33
# 0.40697842768206166 33
# 0.3952511944404228 33
# 0.3904734327493847 33
# 0.3822209352830462 33
# 0.40726798899667005 33
# 0.3839583031706964 33
# 0.41856088026639643 33

# %%
# print(w_samples[0,:])
sample_from_surface = True
rset = RSetGAMs(filepath)
w_samples = rset.sample_in_ellipsoid(rset.H, rset.w_orig, n_samples=200,sample_from_surface=sample_from_surface)
count = 0
for key, values in rset.xlabel.items():
    print(key,values)
    plt.figure(figsize=(5.5,4))
    l = count
    r = count +len(values)-1
    count += len(values)-1

    if key == "bias":
        continue

    for i, w_new in enumerate(w_samples):
        plt.step(values, np.hstack((w_new[l], w_new[l:r])), c="red", alpha=0.05)

    plt.step(values, np.hstack((rset.w_orig[l], rset.w_orig[l:r])), c="dimgray", linewidth=2)
    
    plt.xlabel(key, fontsize=22)
    plt.ylabel("predicted logit", fontsize=22)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
# Out:
# bias [0, 1]
# sex=female [0, 0.0, 1.0]
# age [18, 19.0, 20.0, 22.0, 24.0, 27.0, 29.0, 33.0, 36.0, 39.0, 40.0, 52.0, 83.0, 96.0]
# juv_misd_count [0, 0.0, 5.0, 13.0]
# juvenile_crimes [0, 0.0, 7.0, 20.0]
# priors_count [0, 0.0, 1.0, 2.0, 5.0, 7.0, 9.0, 15.0, 20.0, 38.0]
# current_charge_degree=felony [0, 0.0, 1.0]

# %% [markdown]
# ## Application 2: get variable importance range.

# %%
variable_importance_range(filepath, mip=False, plot_shape=True, plot_vir=True)
# Out:
# Pregnancies
# ----------------------variable importance Minus----------------------
# Second solve time: 0.001136294
# log obj: 0.37852442668501773 rset_bound: 0.3785348067007739
# Second solve time: 0.001009304
# log obj: 0.39446020551924704 rset_bound: 0.3785348067007739
# ----------------------variable importance plus LP--------------------
# time: 0.12797999382019043
# log obj: 0.7788724774161648 rset_bound: 0.3785348067007739
# /usr/project/xtmp/vb97/GAM_Rashomon_Sets/GAMsRashomonSet/src/rset_app.py:120: UserWarning: solution is out of the Rset.
#   warnings.warn("solution is out of the Rset. ")
# time: 0.06427264213562012
# log obj: 0.8808327960563094 rset_bound: 0.3785348067007739
# Glucose
# ----------------------variable importance Minus----------------------
# Second solve time: 0.001249085
# log obj: 0.4950970232079899 rset_bound: 0.3785348067007739
# Second solve time: 0.001160664
# log obj: 0.5082962682287859 rset_bound: 0.3785348067007739
# ----------------------variable importance plus LP--------------------
# time: 1.046985149383545
# log obj: 0.6907782648213936 rset_bound: 0.3785348067007739
# time: 0.5594604015350342
# log obj: 0.8808344914744088 rset_bound: 0.3785348067007739
# BloodPressure
# ----------------------variable importance Minus----------------------
# Second solve time: 0.001285521
# log obj: 0.3914463180164351 rset_bound: 0.3785348067007739
# Second solve time: 0.001155863
# log obj: 0.4129716881172303 rset_bound: 0.3785348067007739
# ----------------------variable importance plus LP--------------------
# time: 1.178006887435913
# log obj: 0.8048573950497298 rset_bound: 0.3785348067007739
# time: 0.5817475318908691
# log obj: 0.8808332809305257 rset_bound: 0.3785348067007739
# SkinThickness
# ----------------------variable importance Minus----------------------
# Second solve time: 0.00116907
# log obj: 0.3785306024626782 rset_bound: 0.3785348067007739
# Second solve time: 0.00110277
# log obj: 0.39303194473691533 rset_bound: 0.3785348067007739
# ----------------------variable importance plus LP--------------------
# time: 0.13182759284973145
# log obj: 0.7923393673627944 rset_bound: 0.3785348067007739
# time: 0.06659746170043945
# log obj: 0.8808325884841823 rset_bound: 0.3785348067007739
# Insulin
# ----------------------variable importance Minus----------------------
# Second solve time: 0.001299347
# log obj: 0.3983012918755387 rset_bound: 0.3785348067007739
# Second solve time: 0.001354596
# log obj: 0.4001756129797832 rset_bound: 0.3785348067007739
# ----------------------variable importance plus LP--------------------
# time: 0.5389647483825684
# log obj: 0.8233686311342139 rset_bound: 0.3785348067007739
# time: 0.28824687004089355
# log obj: 0.8815725056299017 rset_bound: 0.3785348067007739
# BMI
# ----------------------variable importance Minus----------------------
# Second solve time: 0.001253285
# log obj: 0.4383899868525662 rset_bound: 0.3785348067007739
# Second solve time: 0.001205998
# log obj: 0.462687700802437 rset_bound: 0.3785348067007739
# ----------------------variable importance plus LP--------------------
# time: 4.45785927772522
# log obj: 0.7286103399159932 rset_bound: 0.3785348067007739
# time: 2.3836426734924316
# log obj: 0.8808326866682268 rset_bound: 0.3785348067007739
# DiabetesPedigreeFunction
# ----------------------variable importance Minus----------------------
# Second solve time: 0.001307419
# log obj: 0.41103822896070336 rset_bound: 0.3785348067007739
# Second solve time: 0.001218976
# log obj: 0.4305907145258708 rset_bound: 0.3785348067007739
# ----------------------variable importance plus LP--------------------
# time: 2.154299736022949
# log obj: 1.0091323790808906 rset_bound: 0.3785348067007739
# time: 1.215005874633789
# log obj: 0.9244654769356493 rset_bound: 0.3785348067007739
# Age
# ----------------------variable importance Minus----------------------
# Second solve time: 0.001222179
# log obj: 0.41236726026587034 rset_bound: 0.3785348067007739
# Second solve time: 0.001162047
# log obj: 0.4284780153512599 rset_bound: 0.3785348067007739
# ----------------------variable importance plus LP--------------------
# time: 0.5139069557189941
# log obj: 0.7593751830849846 rset_bound: 0.3785348067007739
# time: 0.2718632221221924
# log obj: 0.8808338862591407 rset_bound: 0.3785348067007739

# %% [markdown]
# ## Application 3: get monotonically increasing or decreasing shape function.
#
# Suppose we want to make ``BlooedPressure'' monotonically decreasing.

# %%
get_monotone(filepath, f="age", direction="increase")
# Out:
# feature age
# ----------------------monotonicity----------------------
# Second solve time: 0.000177529
# log obj: 0.6857934710687632 rset_bound: 0.7079380563928068
# updated w [-0.01327659 -0.04322001 -0.04322001 -0.04322001 -0.04322001 -0.04322001
#  -0.04322001 -0.04322001 -0.04322001 -0.10788061  0.36572575 -0.80002133
#  -0.42790235 -0.0638881   0.27140348  0.43210457  0.72722035  1.2696048 ]

# %% [markdown]
# ## Application 4: get user preferred shape functions

# %%
# w_user = np.array([ 1.55089258, 0.74716894,  0.74716894, -0.12313043, -0.65963492])
w_user = np.array([ 1.55089258, -0.12313043,  -0.12313043, -0.12313043, -0.65963492])
get_projection(filepath, f="BloodPressure", w_user=w_user)
# Out:
# feature BloodPressure
# ----------------------projection----------------------
# Second solve time: 0.001784264
# Second solve time: 0.001996035
# log obj: 0.37642143295015484 rset_bound: 0.37657937589518325
# w_fix [-1.13806888 -0.09460456  0.47839286  0.98775417 -1.97208434 -0.23773331
#   0.63338512  2.51487398  1.55212841 -0.14711962  0.1001726  -0.12192577
#  -0.65984924  0.0272953  -2.36504238  0.09826116 -0.53466764 -7.98369308
#   2.47159251 -1.75653858 -0.48758746  0.10912645  0.65379258 -0.2631445
#   1.1084895   4.55958999 -0.87621442 -0.08466368  0.48294889  3.8096931
#  -3.97142533  2.68868138 -0.69359117  0.47979827  1.17242448 -1.06000037]
# w_not_fix [-1.11510728e+00 -6.89724069e-02  4.76195244e-01  9.86653719e-01
#  -1.96176959e+00 -2.14534475e-01  6.25590598e-01  2.51411183e+00
#   1.54494064e+00 -1.57641555e-01  7.76599781e-03 -1.72318369e-01
#  -6.75858381e-01  4.93748999e-02 -2.36392040e+00  1.16334430e-01
#  -5.30696975e-01 -7.98264545e+00  2.47140600e+00 -1.74901387e+00
#  -4.84235936e-01  1.05008890e-01  6.73376964e-01 -2.61083682e-01
#   1.10586442e+00  4.55700286e+00 -8.71480854e-01 -7.30538340e-02
#   4.88589690e-01  3.80996403e+00 -3.97042383e+00  2.68839087e+00
#  -6.65883065e-01  4.88988956e-01  1.16090731e+00 -1.06273697e+00]
# /home/users/vb97/.local/lib/python3.10/site-packages/cvxpy/reductions/solvers/solving_chain.py:336: FutureWarning:
#     Your problem is being solved with the ECOS solver by default. Starting in
#     CVXPY 1.5.0, Clarabel will be used as the default solver instead. To continue
#     using ECOS, specify the ECOS solver explicitly using the ``solver=cp.ECOS``
#     argument to the ``problem.solve`` method.
#
#   warnings.warn(ECOS_DEPRECATION_MSG, FutureWarning)

# %% [markdown]
# ## Application 5: explore the changes in shape functions.
#
# There is a jump in the ``BloodPressure'' shape function around 60. We want to check if this pattern is also available in other models within the Rashomon set. We can sample models from the Rashomon set and calculate the frequency of the jump.

# %%
cnt = test_jump(filepath, n_samples=10000, i=9, j=10, k=11)
# Out:
# proportion: 1.0

# %%
# Things to discuss with Jiachang
# 1. How to integrate FastSparse

w = pkl.load(open(betas_fastSparse,'rb'))['w_orig']

# print(w)

# %% [markdown]
# # Comparing single support set vs multiple support set GAM Rashomon sets

# %% [markdown]
# ## FastSparse for Single Support Set GAM

# %%
from src.utils import one_hot_encoding
import numpy as np
import pandas as pd
import pickle
# !pip install rpy2
from src.run_app import *
from src.prepare_gam import *
from matplotlib import pyplot as plt
import pickle as pkl
from src.utils import *

dname = "compas"
l0 = 0.001
l2 = 0.5
m = 1.01
betas_fastSparse = prepare_sparse_gam('compas',lamb0=l0,lamb2=l2,multiplier=1.01)
filepath = "{}_{}_{}_{}.p".format(dname, l0, l2, m)

w_samples = get_models_from_rset(filepath, n_samples=100, plot_shape=True,sample_from_surface=False)

# %%
import numpy as np
import pandas as pd
import pickle
# !pip install rpy2
from src.run_app import *
from src.prepare_gam import *
from matplotlib import pyplot as plt
import pickle as pkl
from src import utils

dataset_name = 'compas'
path = '/usr/project/xtmp/vb97/GAM_Rashomon_Sets/GAMsRashomonSet/datasets/{}.csv'.format(
    dataset_name)
dataset = pd.read_csv(path)
dataset.iloc[:,-1][dataset.iloc[:,-1] == 0] = -1
X,y = dataset.iloc[:,:-1], dataset.iloc[:,-1]
X_one_hot, count = one_hot_encoding(X,one_hot=True)
y = pd.DataFrame(y) # {0,1}
header = list(X_one_hot.columns)
header = pd.Index(["intercept"] + header)
header = header.astype("object")
print("header dimension", len(header), flush=True)
X_one_hot, y = utils.get_X_y(X_one_hot, y) # add a column of one to X_orig and make y in {1,-1}
# X_one_hot = ~X_one_hot
y = y[:,-1]
print(X_one_hot.shape,y.shape)
# Out:
# header dimension 142
# (6907, 142) (6907,)

# %%
mean_loss = 0
for i in range(len(w_samples)):
    w0 = w_samples[i,:]
    X_fastsparse = pkl.load(open(betas_fastSparse,'rb'))['X']
    logits = X_fastsparse@w0
    y_pred = np.exp(logits)/(1+np.exp(logits))
    y_pred[y_pred > 0.5] = 1
    y_pred[y_pred <=0.5] = -1
    mean_loss += (y!=y_pred).mean()
print(mean_loss / len(w_samples))
# len(pkl.load(open(betas_fastSparse,'rb'))['header_new']))
# Out:
# 0.37443607933980033

# %% [markdown]
# ## FasterRisk for multiple support set GAMs

# %%
from FasterRisk.src.fasterrisk import fasterrisk

rs = fasterrisk.RiskScoreOptimizer(X_one_hot,y,k=10,lb = -100,ub=100,gap_tolerance=0.01,select_top_m=500)
rs.optimize(generate_non_integer_solution=True)
sparseDiversePool_beta0 = rs.sparseDiversePool_beta0
sparseDiversePool_betas = rs.sparseDiversePool_betas

# %%
# GAMS identify artefacts in the data -> Zack
# Regularization based on data distribution? 
# Constraint for hard penalty (l0) -> evaluate it on soft penalty (l2)
# Histogram of support sets (overlapping) 
# Domain knowledge -> support sets
# modify beam search to only include support sets that are sufficiently different 
# (where a diversity parameter is specified by the user)
# 
print(sparseDiversePool_betas.shape)
# Out:
# (301, 142)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from collections import defaultdict
from tqdm import tqdm

# Input data
def get_feature_thresholds(weights, columns):
    # Extract features and thresholds
    feature_thresholds = {}
    for col, weight in zip(columns, weights):
        match = re.search(r'([a-zA-Z]+)', col)
        if match:
            feature = match.group(1)
            # threshold = col
            threshold = re.findall(r'[\d.]+', col)
            if feature == 'juv':
                feature = 'juv_misd_count'
            if feature == 'juvenile':
                feature = 'juvenile_crimes'
            if feature not in feature_thresholds:
                feature_thresholds[feature] = []
            # if feature == 'current':
            #     print(threshold,list(map(float, threshold)), weight)
            feature_thresholds[feature].append((list(map(float, threshold)), weight))
    
    return feature_thresholds
    
def plot_gam(X, X_one_hot, header, list_of_weights):
    # Create subplots
    num_features = X.shape[1]
    # fig, axes = plt.subplots(num_features-2, 1, figsize=(10, 3 * num_features), sharex=False)
    fig = plt.figure(figsize=(13,3))
    fig.set_dpi(500)
    ax_dict = defaultdict(int)
    if num_features == 1:
        axes = [axes]  # Ensure axes is iterable for a single feature
    counter = 0
    union_of_support_sets = defaultdict(int)
    for i in tqdm(range(len(list_of_weights))):
        weights = list_of_weights[i,:]
        columns = header[np.nonzero(weights)[0]]
        weights = weights[np.nonzero(weights)[0]]
        for column in columns:
            union_of_support_sets[column] += 1
        
        feature_thresholds = get_feature_thresholds(weights, columns)
        
        for feature, thresholds_weights in feature_thresholds.items():
            if feature != 'sex' and feature != 'current':
                if feature not in ax_dict:
                    ax = fig.add_axes([0.05, 0.1+counter, 0.2, 0.8])
                    ax_dict[feature] = ax
                    counter += 1
                else:
                    ax = ax_dict[feature]
                thresholds, feature_weights = zip(*thresholds_weights)
                
                x = range(len(thresholds))  # X-axis positions for thresholds
                x_vals, y_vals = [],[]
                x_vals.append(0)
                y_vals.append(feature_weights[0])
                flag = False
                for i in range(len(thresholds) - 1):
                    x_vals.append(thresholds[i][0])
                    y_vals.append(feature_weights[i])
                if flag:
                    continue
                # For the last value of the interval, add it once more
                
                x_vals.append(thresholds[-1][0])
                y_vals.append(feature_weights[-1])
                # if feature == 'current':
                #     print(feature,thresholds,x_vals, y_vals)
                # x_vals.append(thresholds[-1][0] + 1)  # Extend beyond the last point by 1 (or as needed)
                # y_vals.append(feature_weights[-1])  # Keep the same weight
                ax.step(x_vals, y_vals, where="post", color='r',alpha=0.1)
                ax.set_ylabel("Predicted Logit")
                ax.set_title(feature)
                # ax.legend()
    # plt.xlabel("Thresholds")
    plt.tight_layout()
    plt.show()
    return union_of_support_sets

union_of_support_sets = plot_gam(X,X_one_hot, header, sparseDiversePool_betas[:100,:])
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 311.10it/s]
# /tmp/ipykernel_1209757/3438451275.py:86: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
mean_loss = 0
for i in range(len(sparseDiversePool_betas)):
    wi = sparseDiversePool_betas[i,:]
    intercepti = sparseDiversePool_beta0[i]
    y_pred = np.exp(X_one_hot@wi + intercepti)/(1+np.exp(X_one_hot@wi + intercepti))
    y_pred[y_pred > 0.5] = 1
    y_pred[y_pred <=0.5] = -1
    mean_loss += (y!=y_pred).mean()
    # print((y!=y_pred).mean())
print(mean_loss/len(sparseDiversePool_betas))
# Out:
# 0.331854582500203

# %%
import matplotlib.pyplot as plt
from collections import defaultdict

# Given dictionary
sorted_data = dict(sorted(union_of_support_sets.items(), key=lambda x: x[1], reverse=True))

# Prepare data for histogram
keys = list(sorted_data.keys())
values = list(sorted_data.values())

# # Prepare data for histogram
# keys = list(data.keys())
# values = list(data.values())

# Plot histogram
plt.figure(figsize=(15, 6))
plt.bar(keys, values, color='blue', alpha=0.7)
plt.xticks(rotation=90, fontsize=8)
plt.ylabel('Count')
plt.title('Histogram of Features',fontsize=20)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 from collections import defaultdict
#       4 # Given dictionary
# ----> 5 sorted_data = dict(sorted(union_of_support_sets.items(), key=lambda x: x[1], reverse=True))
#       7 # Prepare data for histogram
#       8 keys = list(sorted_data.keys())
#
# NameError: name 'union_of_support_sets' is not defined

# %%
header = pkl.load(open(betas_fastSparse,'rb'))['header_new']
header = [i.replace('.0', '') for i in header]
print(keys[:10],header)
# for key in keys[:15]:
#     print(header,key)
    # if key in header:
    #     print(key)
# Out:
# ['19<age<=20', 'priors_count<=0', '0<priors_count<=1', '1<priors_count<=2', '18<age<=19', '20<age<=21', '21<age<=22', '22<age<=23', 'juvenile_crimes<=0', '2<priors_count<=3'] ['intercept', 'age<=22', '22<age<=27', '27<age<=32', '32<age<=33', '33<age<=36', '36<age<=96', 'juvenile_crimes<=0', '0<juvenile_crimes<=20', 'priors_count<=0', '0<priors_count<=1', '1<priors_count<=2', '2<priors_count<=3', '3<priors_count<=4', '4<priors_count<=5', '5<priors_count<=6', '6<priors_count<=7', '7<priors_count<=38']
