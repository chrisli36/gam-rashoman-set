# %%
from src.run_app import *
from src.prepare_gam import *
from src.utils import *
from gam_rs_utils.binarize_dataset import binarize_dataset
from gam_rs_utils.utils import *
from FasterRisk.src.fasterrisk import fasterrisk

import pickle
import numpy as np
from time import time

def rashomon_set_size(swaps, gap_tolerance):
    rs = fasterrisk.RiskScoreOptimizer(X_one_hot, y, k=10, lb=-100, ub=100, gap_tolerance=gap_tolerance, select_top_m=-1)
    rs.optimize_with_swaps(swaps=swaps, fanout_decay=1)
    return rs.sparseDiversePool_betas, rs.sparseDiversePool_beta0

def bisect_left_one(func, low, high, tol=1e-6):
    """Find leftmost such that func(x) >= 1"""
    record = []
    while high - low > tol:
        mid = (low + high) / 2
        start = time()
        betas, beta0 = func(mid)
        end = time()
        num_solutions = betas.shape[0]
        print(f"tried {mid}, got {num_solutions} solutions, took {end - start:.2f} seconds")
        record.append((mid, num_solutions, end - start, betas, beta0))
        if num_solutions < 1:
            low = mid
        else:
            high = mid
    return record

results = []
for dataset_name, left, right in [('bank', 0.0005, 0.001), ('compas', 0.0001, 0.002), ('diabetes', 0.0, 0.002)]:
    path = 'datasets/{}.csv'.format(dataset_name)
    dataset = pd.read_csv(path)
    df, thresholds, header, threshold_guess_time = binarize_dataset(dataset, 100)
    X, y = df.iloc[:, :-1], df.iloc[:, -1]

    header = list(X.columns)
    header = pd.Index(["intercept"] + header)
    header = header.astype("object")

    X_one_hot, y = utils.get_X_y(X, y)
    print(f"Dataset: {dataset_name}, shape: {dataset.shape}")
    print(f"Binarized shape: {X_one_hot.shape}")

    for swaps in range(1, 6):
        print(f"Swapping {swaps} times")
        gam_results = bisect_left_one(lambda x: rashomon_set_size(swaps, x), left, right)
        results.extend([(dataset_name, swaps, *gr) for gr in gam_results])

with open("results/swaps_results.pkl", "wb") as f:
    pickle.dump(results, f)
# Out:
# Dataset: bank, shape: (4521, 17)
# Binarized shape: (4521, 38)
# Swapping 1 times
# tried 0.00075, got 2 solutions, took 11.38 seconds
# tried 0.000625, got 1 solutions, took 11.58 seconds
# tried 0.0005625000000000001, got 1 solutions, took 9.60 seconds
# tried 0.00053125, got 0 solutions, took 10.57 seconds
# tried 0.000546875, got 0 solutions, took 14.39 seconds
# tried 0.0005546875000000001, got 1 solutions, took 12.54 seconds
# tried 0.0005507812500000001, got 0 solutions, took 10.82 seconds
# tried 0.0005527343750000001, got 1 solutions, took 11.70 seconds
# tried 0.0005517578125000001, got 0 solutions, took 10.20 seconds
# Swapping 2 times
# tried 0.00075, got 0 solutions, took 13.46 seconds
# tried 0.000875, got 21 solutions, took 12.69 seconds
# tried 0.0008125000000000001, got 0 solutions, took 14.15 seconds
# tried 0.0008437500000000001, got 12 solutions, took 11.33 seconds
# tried 0.0008281250000000001, got 18 solutions, took 11.84 seconds
# tried 0.0008203125000000001, got 0 solutions, took 13.14 seconds
# tried 0.0008242187500000001, got 0 solutions, took 13.91 seconds
# tried 0.0008261718750000001, got 12 solutions, took 12.32 seconds
# tried 0.0008251953125000001, got 19 solutions, took 14.93 seconds
# Swapping 3 times
# tried 0.00075, got 0 solutions, took 10.59 seconds
# tried 0.000875, got 33 solutions, took 17.80 seconds
# tried 0.0008125000000000001, got 0 solutions, took 13.88 seconds
# tried 0.0008437500000000001, got 32 solutions, took 18.10 seconds
# tried 0.0008281250000000001, got 35 solutions, took 17.37 seconds
# tried 0.0008203125000000001, got 0 solutions, took 14.01 seconds
# tried 0.0008242187500000001, got 0 solutions, took 13.45 seconds
# tried 0.0008261718750000001, got 46 solutions, took 22.52 seconds
# tried 0.0008251953125000001, got 36 solutions, took 22.43 seconds
# Swapping 4 times
# tried 0.00075, got 0 solutions, took 32.24 seconds
# tried 0.000875, got 21 solutions, took 16.44 seconds
# tried 0.0008125000000000001, got 0 solutions, took 17.69 seconds
# tried 0.0008437500000000001, got 15 solutions, took 15.73 seconds
# tried 0.0008281250000000001, got 9 solutions, took 17.51 seconds
# tried 0.0008203125000000001, got 0 solutions, took 14.39 seconds
# tried 0.0008242187500000001, got 0 solutions, took 13.64 seconds
# tried 0.0008261718750000001, got 8 solutions, took 17.27 seconds
# tried 0.0008251953125000001, got 9 solutions, took 20.18 seconds
# Swapping 5 times
# tried 0.00075, got 0 solutions, took 26.25 seconds
# tried 0.000875, got 0 solutions, took 16.87 seconds
# tried 0.0009375, got 1 solutions, took 13.38 seconds
# tried 0.0009062499999999999, got 0 solutions, took 16.27 seconds
# tried 0.000921875, got 1 solutions, took 19.48 seconds
# tried 0.0009140624999999999, got 1 solutions, took 13.60 seconds
# tried 0.0009101562499999999, got 1 solutions, took 14.36 seconds
# tried 0.0009082031249999999, got 0 solutions, took 16.95 seconds
# tried 0.0009091796874999999, got 1 solutions, took 23.75 seconds
# Dataset: compas, shape: (6907, 8)
# Binarized shape: (6907, 29)
# Swapping 1 times
# tried 0.00105, got 10 solutions, took 10.86 seconds
# tried 0.000575, got 4 solutions, took 16.17 seconds
# tried 0.0003375, got 3 solutions, took 12.93 seconds
# tried 0.00021875, got 2 solutions, took 15.26 seconds
# tried 0.000159375, got 1 solutions, took 13.98 seconds
# tried 0.0001296875, got 0 solutions, took 10.19 seconds
# tried 0.00014453125000000002, got 0 solutions, took 12.89 seconds
# tried 0.00015195312500000002, got 1 solutions, took 15.50 seconds
# tried 0.00014824218750000002, got 1 solutions, took 12.25 seconds
# tried 0.00014638671875000003, got 1 solutions, took 12.15 seconds
# tried 0.00014545898437500003, got 1 solutions, took 11.60 seconds
# Swapping 2 times
# tried 0.00105, got 20 solutions, took 16.01 seconds
# tried 0.000575, got 3 solutions, took 11.52 seconds
# tried 0.0003375, got 1 solutions, took 12.35 seconds
# tried 0.00021875, got 1 solutions, took 9.17 seconds
# tried 0.000159375, got 0 solutions, took 11.12 seconds
# tried 0.0001890625, got 0 solutions, took 14.55 seconds
# tried 0.00020390624999999999, got 0 solutions, took 14.57 seconds
# tried 0.00021132812499999998, got 0 solutions, took 11.02 seconds
# tried 0.0002150390625, got 0 solutions, took 10.42 seconds
# tried 0.00021689453125000002, got 1 solutions, took 14.96 seconds
# tried 0.000215966796875, got 0 solutions, took 12.44 seconds
# Swapping 3 times
# tried 0.00105, got 12 solutions, took 17.23 seconds
# tried 0.000575, got 1 solutions, took 11.96 seconds
# tried 0.0003375, got 0 solutions, took 12.04 seconds
# tried 0.00045625, got 0 solutions, took 10.96 seconds
# tried 0.000515625, got 1 solutions, took 11.66 seconds
# tried 0.00048593750000000004, got 0 solutions, took 9.28 seconds
# tried 0.00050078125, got 1 solutions, took 10.33 seconds
# tried 0.0004933593750000001, got 0 solutions, took 10.58 seconds
# tried 0.0004970703125000001, got 1 solutions, took 11.89 seconds
# tried 0.0004952148437500001, got 0 solutions, took 13.99 seconds
# tried 0.0004961425781250001, got 0 solutions, took 11.41 seconds
# Swapping 4 times
# tried 0.00105, got 1 solutions, took 13.07 seconds
# tried 0.000575, got 0 solutions, took 14.95 seconds
# tried 0.0008125, got 0 solutions, took 12.71 seconds
# tried 0.00093125, got 1 solutions, took 12.35 seconds
# tried 0.000871875, got 0 solutions, took 16.25 seconds
# tried 0.0009015625, got 0 solutions, took 11.89 seconds
# tried 0.00091640625, got 0 solutions, took 12.25 seconds
# tried 0.000923828125, got 1 solutions, took 12.05 seconds
# tried 0.0009201171874999999, got 0 solutions, took 12.18 seconds
# tried 0.0009219726562499999, got 0 solutions, took 16.54 seconds
# tried 0.000922900390625, got 0 solutions, took 9.98 seconds
# Swapping 5 times
# tried 0.00105, got 0 solutions, took 10.59 seconds
# tried 0.0015249999999999999, got 0 solutions, took 20.86 seconds
# tried 0.0017625, got 0 solutions, took 22.60 seconds
# tried 0.0018812500000000001, got 1 solutions, took 28.04 seconds
# tried 0.0018218750000000001, got 1 solutions, took 25.15 seconds
# tried 0.0017921875, got 0 solutions, took 24.15 seconds
# tried 0.00180703125, got 1 solutions, took 28.88 seconds
# tried 0.001799609375, got 1 solutions, took 20.88 seconds
# tried 0.0017958984375, got 1 solutions, took 22.21 seconds
# tried 0.00179404296875, got 0 solutions, took 21.55 seconds
# tried 0.001794970703125, got 0 solutions, took 23.53 seconds
# Dataset: diabetes, shape: (768, 9)
# Binarized shape: (768, 36)
# Swapping 1 times
# tried 0.001, got 2 solutions, took 2.20 seconds
# tried 0.0005, got 2 solutions, took 2.04 seconds
# tried 0.00025, got 2 solutions, took 1.91 seconds
# tried 0.000125, got 2 solutions, took 1.89 seconds
# tried 6.25e-05, got 2 solutions, took 1.94 seconds
# tried 3.125e-05, got 2 solutions, took 1.91 seconds
# tried 1.5625e-05, got 2 solutions, took 1.82 seconds
# tried 7.8125e-06, got 2 solutions, took 1.84 seconds
# tried 3.90625e-06, got 2 solutions, took 1.87 seconds
# tried 1.953125e-06, got 2 solutions, took 1.93 seconds
# tried 9.765625e-07, got 2 solutions, took 1.88 seconds
# Swapping 2 times
# tried 0.001, got 4 solutions, took 1.90 seconds
# tried 0.0005, got 4 solutions, took 1.86 seconds
# tried 0.00025, got 4 solutions, took 1.95 seconds
# tried 0.000125, got 1 solutions, took 1.90 seconds
# tried 6.25e-05, got 3 solutions, took 1.92 seconds
# tried 3.125e-05, got 3 solutions, took 1.82 seconds
# tried 1.5625e-05, got 2 solutions, took 1.87 seconds
# tried 7.8125e-06, got 1 solutions, took 1.92 seconds
# tried 3.90625e-06, got 2 solutions, took 1.85 seconds
# tried 1.953125e-06, got 2 solutions, took 1.92 seconds
# tried 9.765625e-07, got 1 solutions, took 1.78 seconds
# Swapping 3 times
# tried 0.001, got 1 solutions, took 1.93 seconds
# tried 0.0005, got 1 solutions, took 1.94 seconds
# tried 0.00025, got 0 solutions, took 1.94 seconds
# tried 0.000375, got 0 solutions, took 1.92 seconds
# tried 0.0004375, got 0 solutions, took 1.87 seconds
# tried 0.00046875, got 0 solutions, took 1.92 seconds
# tried 0.000484375, got 0 solutions, took 1.93 seconds
# tried 0.0004921875, got 1 solutions, took 1.91 seconds
# tried 0.00048828125, got 1 solutions, took 1.93 seconds
# tried 0.000486328125, got 0 solutions, took 1.82 seconds
# tried 0.0004873046875, got 0 solutions, took 1.85 seconds
# Swapping 4 times
# tried 0.001, got 0 solutions, took 1.88 seconds
# tried 0.0015, got 0 solutions, took 2.03 seconds
# tried 0.00175, got 0 solutions, took 1.98 seconds
# tried 0.001875, got 0 solutions, took 1.99 seconds
# tried 0.0019375, got 1 solutions, took 2.05 seconds
# tried 0.00190625, got 0 solutions, took 1.99 seconds
# tried 0.001921875, got 0 solutions, took 1.97 seconds
# tried 0.0019296875, got 0 solutions, took 2.01 seconds
# tried 0.00193359375, got 0 solutions, took 1.96 seconds
# tried 0.001935546875, got 0 solutions, took 2.01 seconds
# tried 0.0019365234375, got 0 solutions, took 2.00 seconds
# Swapping 5 times
# tried 0.001, got 0 solutions, took 1.92 seconds
# tried 0.0015, got 0 solutions, took 2.06 seconds
# tried 0.00175, got 0 solutions, took 1.98 seconds
# tried 0.001875, got 0 solutions, took 1.97 seconds
# tried 0.0019375, got 0 solutions, took 1.99 seconds
# tried 0.00196875, got 0 solutions, took 1.97 seconds
# tried 0.001984375, got 0 solutions, took 1.95 seconds
# tried 0.0019921875, got 0 solutions, took 2.19 seconds
# tried 0.00199609375, got 0 solutions, took 2.09 seconds
# tried 0.0019980468750000003, got 0 solutions, took 2.14 seconds
# tried 0.0019990234375, got 0 solutions, took 2.07 seconds

# %%
import pickle
with open("results/swaps_results.pkl", "rb") as f:
    results = pickle.load(f)

# %%
import pandas as pd
import matplotlib.pyplot as plt

results = pd.DataFrame(results, columns=["dataset", "swaps", "gap", "num_solutions", "time", "betas", "beta0"])
# results = results[~results["dataset"].isin(["bank", "diabetes"])]

def plot_swaps(results):
    fig, ax = plt.subplots()
    for dataset_name, data_group in results.groupby("dataset"):
        swap_vals = []
        gap_vals = []
        for swaps, swap_group in data_group.groupby("swaps"):
            yields_solutions = swap_group[swap_group["num_solutions"] > 0]
            if not yields_solutions.empty:
                min_gap = yields_solutions["gap"].min()
                swap_vals.append(swaps)
                gap_vals.append(min_gap)
                print(dataset_name, swaps, min_gap)
        sorted_pairs = sorted(zip(swap_vals, gap_vals))
        swap_vals, gap_vals = zip(*sorted_pairs)
        ax.plot(swap_vals, gap_vals, label=dataset_name, marker="o")
    ax.set_xlabel("Number of swaps")
    ax.set_ylabel("Gap")
    ax.legend()
    plt.show()
plot_swaps(results)
# Out:
# bank 1 0.0005527343750000001
# bank 2 0.0008251953125000001
# bank 3 0.0008251953125000001
# bank 4 0.0008251953125000001
# bank 5 0.0009091796874999999
# compas 1 0.00014545898437500003
# compas 2 0.00021689453125000002
# compas 3 0.0004970703125000001
# compas 4 0.000923828125
# compas 5 0.0017958984375
# diabetes 1 9.765625e-07
# diabetes 2 9.765625e-07
# diabetes 3 0.00048828125
# diabetes 4 0.0019375
